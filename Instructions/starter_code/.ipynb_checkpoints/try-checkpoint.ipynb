# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
input_file = "../output_data/cities.csv"
# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
vac_df =  pd.read_csv(input_file)
vac_df
# Out:
#      Unnamed: 0                           coord  \
# 0             0    {'lon': -68.3, 'lat': -54.8}
# 1             1   {'lon': -46.05, 'lat': 60.92}
# 2             2   {'lon': 19.23, 'lat': -34.42}
# 3             3  {'lon': -70.92, 'lat': -53.15}
# 4             4   {'lon': -92.27, 'lat': 15.77}
# ..          ...                             ...
# 495         495    {'lon': 86.15, 'lat': 41.76}
# 496         496    {'lon': 20.58, 'lat': 32.53}
# 497         497                             NaN
# 498         498                             NaN
# 499         499     {'lon': 8.48, 'lat': 35.86}
#
#                                                weather      base  \
# 0    [{'id': 301, 'main': 'Drizzle', 'description':...  stations
# 1    [{'id': 300, 'main': 'Drizzle', 'description':...  stations
# 2    [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 3    [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 4    [{'id': 804, 'main': 'Clouds', 'description': ...  stations
# ..                                                 ...       ...
# 495  [{'id': 801, 'main': 'Clouds', 'description': ...  stations
# 496  [{'id': 800, 'main': 'Clear', 'description': '...  stations
# 497                                                NaN       NaN
# 498                                                NaN       NaN
# 499  [{'id': 803, 'main': 'Clouds', 'description': ...  stations
#
#                                                   main  visibility  \
# 0    {'temp': 279.15, 'feels_like': 270.81, 'temp_m...     10000.0
# 1    {'temp': 280.15, 'feels_like': 271.03, 'temp_m...         NaN
# 2    {'temp': 289.82, 'feels_like': 289.19, 'temp_m...         NaN
# 3    {'temp': 283.92, 'feels_like': 275.38, 'temp_m...     10000.0
# 4    {'temp': 306.1, 'feels_like': 306.66, 'temp_mi...         NaN
# ..                                                 ...         ...
# 495  {'temp': 288.41, 'feels_like': 287.36, 'temp_m...         NaN
# 496  {'temp': 288.79, 'feels_like': 285.29, 'temp_m...         NaN
# 497                                                NaN         NaN
# 498                                                NaN         NaN
# 499  {'temp': 294.15, 'feels_like': 289.74, 'temp_m...     10000.0
#
#                                           wind       clouds            dt  \
# 0                  {'speed': 10.3, 'deg': 230}  {'all': 75}  1.586711e+09
# 1                    {'speed': 9.3, 'deg': 70}  {'all': 98}  1.586711e+09
# 2    {'speed': 1.79, 'deg': 281, 'gust': 3.58}  {'all': 29}  1.586711e+09
# 3    {'speed': 10.8, 'deg': 280, 'gust': 15.9}  {'all': 40}  1.586710e+09
# 4                   {'speed': 1.5, 'deg': 279}  {'all': 93}  1.586711e+09
# ..                                         ...          ...           ...
# 495   {'speed': 1.34, 'deg': 65, 'gust': 3.58}  {'all': 14}  1.586711e+09
# 496                  {'speed': 5.3, 'deg': 43}   {'all': 1}  1.586711e+09
# 497                                        NaN          NaN           NaN
# 498                                        NaN          NaN           NaN
# 499                 {'speed': 4.1, 'deg': 120}  {'all': 75}  1.586711e+09
#
#                                                    sys  timezone         id  \
# 0    {'type': 1, 'id': 8303, 'country': 'AR', 'sunr...  -10800.0  3833367.0
# 1    {'type': 1, 'id': 47, 'country': 'GL', 'sunris...   -7200.0  3421719.0
# 2    {'type': 3, 'id': 2006131, 'country': 'ZA', 's...    7200.0  3366880.0
# 3    {'type': 1, 'id': 8487, 'country': 'CL', 'sunr...  -10800.0  3874787.0
# 4    {'country': 'MX', 'sunrise': 1586692547, 'suns...  -18000.0  3530935.0
# ..                                                 ...       ...        ...
# 495  {'type': 3, 'id': 2002074, 'country': 'CN', 's...   28800.0  1529376.0
# 496  {'country': 'LY', 'sunrise': 1586664684, 'suns...    7200.0    88834.0
# 497                                                NaN       NaN        NaN
# 498                                                NaN       NaN        NaN
# 499  {'type': 1, 'id': 1075, 'country': 'TN', 'sunr...    3600.0  2469252.0
#
#              name  cod snow rain         message
# 0         Ushuaia  200  NaN  NaN             NaN
# 1          Narsaq  200  NaN  NaN             NaN
# 2        Hermanus  200  NaN  NaN             NaN
# 3    Punta Arenas  200  NaN  NaN             NaN
# 4     Chicomuselo  200  NaN  NaN             NaN
# ..            ...  ...  ...  ...             ...
# 495         Korla  200  NaN  NaN             NaN
# 496        Tūkrah  200  NaN  NaN             NaN
# 497           NaN  404  NaN  NaN  city not found
# 498           NaN  404  NaN  NaN  city not found
# 499  Menzel Salem  200  NaN  NaN             NaN
#
# [500 rows x 17 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
lat_list = []
long_list = []
humidity_list = []
for index, row in vac_df.iterrows():
    #print(index)
    #print ("----------------")
    if isinstance(row["coord"], str):
        split_row = row["coord"].split()
    else :
        continue
    lat_list.append(split_row[3].split("}")[0])
    long_list.append(split_row[1].split(",")[0])
    #print(lat_list)
    #print(long_list)(
    humidity_list.append(float(row["main"].split()[-1].split("}")[0]))
    #print (type(float(row["main"].split()[-1].split("}")[0])))
    if index == 50 :
        break
    #print()
        
#print(lat_list)
#print(long_list)

#all values are in :
gmaps.configure(api_key=g_key)

i = 0
coordinates = []
while(i<len(lat_list)) :
    coordinates.append((float(lat_list[i]),float(long_list[i])))
    i = i + 1

# Customize the size of the figure

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(coordinates, weights=humidity_list, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=2)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#print(vac_df.keys)
clean_data = vac_df.dropna(subset=["weather"])
clean_data
# Out:
#      Unnamed: 0                           coord  \
# 0             0    {'lon': -68.3, 'lat': -54.8}
# 1             1   {'lon': -46.05, 'lat': 60.92}
# 2             2   {'lon': 19.23, 'lat': -34.42}
# 3             3  {'lon': -70.92, 'lat': -53.15}
# 4             4   {'lon': -92.27, 'lat': 15.77}
# ..          ...                             ...
# 493         493    {'lon': 58.53, 'lat': 56.42}
# 494         494    {'lon': 29.09, 'lat': 70.86}
# 495         495    {'lon': 86.15, 'lat': 41.76}
# 496         496    {'lon': 20.58, 'lat': 32.53}
# 499         499     {'lon': 8.48, 'lat': 35.86}
#
#                                                weather      base  \
# 0    [{'id': 301, 'main': 'Drizzle', 'description':...  stations
# 1    [{'id': 300, 'main': 'Drizzle', 'description':...  stations
# 2    [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 3    [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 4    [{'id': 804, 'main': 'Clouds', 'description': ...  stations
# ..                                                 ...       ...
# 493  [{'id': 804, 'main': 'Clouds', 'description': ...  stations
# 494  [{'id': 803, 'main': 'Clouds', 'description': ...  stations
# 495  [{'id': 801, 'main': 'Clouds', 'description': ...  stations
# 496  [{'id': 800, 'main': 'Clear', 'description': '...  stations
# 499  [{'id': 803, 'main': 'Clouds', 'description': ...  stations
#
#                                                   main  visibility  \
# 0    {'temp': 279.15, 'feels_like': 270.81, 'temp_m...     10000.0
# 1    {'temp': 280.15, 'feels_like': 271.03, 'temp_m...         NaN
# 2    {'temp': 289.82, 'feels_like': 289.19, 'temp_m...         NaN
# 3    {'temp': 283.92, 'feels_like': 275.38, 'temp_m...     10000.0
# 4    {'temp': 306.1, 'feels_like': 306.66, 'temp_mi...         NaN
# ..                                                 ...         ...
# 493  {'temp': 276.51, 'feels_like': 272.63, 'temp_m...         NaN
# 494  {'temp': 271.05, 'feels_like': 261.8, 'temp_mi...     10000.0
# 495  {'temp': 288.41, 'feels_like': 287.36, 'temp_m...         NaN
# 496  {'temp': 288.79, 'feels_like': 285.29, 'temp_m...         NaN
# 499  {'temp': 294.15, 'feels_like': 289.74, 'temp_m...     10000.0
#
#                                           wind       clouds            dt  \
# 0                  {'speed': 10.3, 'deg': 230}  {'all': 75}  1.586711e+09
# 1                    {'speed': 9.3, 'deg': 70}  {'all': 98}  1.586711e+09
# 2    {'speed': 1.79, 'deg': 281, 'gust': 3.58}  {'all': 29}  1.586711e+09
# 3    {'speed': 10.8, 'deg': 280, 'gust': 15.9}  {'all': 40}  1.586710e+09
# 4                   {'speed': 1.5, 'deg': 279}  {'all': 93}  1.586711e+09
# ..                                         ...          ...           ...
# 493                {'speed': 2.83, 'deg': 110}  {'all': 94}  1.586711e+09
# 494                 {'speed': 9.3, 'deg': 140}  {'all': 75}  1.586711e+09
# 495   {'speed': 1.34, 'deg': 65, 'gust': 3.58}  {'all': 14}  1.586711e+09
# 496                  {'speed': 5.3, 'deg': 43}   {'all': 1}  1.586711e+09
# 499                 {'speed': 4.1, 'deg': 120}  {'all': 75}  1.586711e+09
#
#                                                    sys  timezone         id  \
# 0    {'type': 1, 'id': 8303, 'country': 'AR', 'sunr...  -10800.0  3833367.0
# 1    {'type': 1, 'id': 47, 'country': 'GL', 'sunris...   -7200.0  3421719.0
# 2    {'type': 3, 'id': 2006131, 'country': 'ZA', 's...    7200.0  3366880.0
# 3    {'type': 1, 'id': 8487, 'country': 'CL', 'sunr...  -10800.0  3874787.0
# 4    {'country': 'MX', 'sunrise': 1586692547, 'suns...  -18000.0  3530935.0
# ..                                                 ...       ...        ...
# 493  {'country': 'RU', 'sunrise': 1586653574, 'suns...   18000.0   580783.0
# 494  {'type': 1, 'id': 1618, 'country': 'NO', 'sunr...    7200.0   780687.0
# 495  {'type': 3, 'id': 2002074, 'country': 'CN', 's...   28800.0  1529376.0
# 496  {'country': 'LY', 'sunrise': 1586664684, 'suns...    7200.0    88834.0
# 499  {'type': 1, 'id': 1075, 'country': 'TN', 'sunr...    3600.0  2469252.0
#
#              name  cod snow rain message
# 0         Ushuaia  200  NaN  NaN     NaN
# 1          Narsaq  200  NaN  NaN     NaN
# 2        Hermanus  200  NaN  NaN     NaN
# 3    Punta Arenas  200  NaN  NaN     NaN
# 4     Chicomuselo  200  NaN  NaN     NaN
# ..            ...  ...  ...  ...     ...
# 493          Arti  200  NaN  NaN     NaN
# 494      Berlevåg  200  NaN  NaN     NaN
# 495         Korla  200  NaN  NaN     NaN
# 496        Tūkrah  200  NaN  NaN     NaN
# 499  Menzel Salem  200  NaN  NaN     NaN
#
# [465 rows x 17 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = clean_data
hotel_df["Hotel Name"] =""


base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="
params = {
    # philadelphia coords,
    "rankby": "distance",
    "type": "restaurant",
    "key": g_key,
}
# use iterrows to iterate through pandas dataframe
for index, row in clean_data.iterrows():

    # get restaurant type from df

    #print(row)
    # add keyword to params dict
    params['city'] = row["name"]
    print ("---------------")
    print(row["coord"].split())
    print ("---------------")
    lat = split_row[3].split("}")[0]
    lng = split_row[1].split(",")[0]
    params['location'] = "" + lat+","+lng+""
    print(row["name"])
    city_name = row["name"]
    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    fullurl = base_url + params["location"]+"&radius=50000&name=hotel&key=" + g_key
    #fullurl = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.80,-96.8&name=hotel&radius=400&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ"
    print (fullurl)
    response = requests.get(fullurl).json()
    #print(response)
    #break
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel is {results[0]['name']}.")
        
        clean_data.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    #break    
    print("------------")
              
hotel_df = clean_data
# Out:
# ---------------
# ["{'lon':", '-68.3,', "'lat':", '-54.8}']
# ---------------
# Ushuaia
# Retrieving Results for Index 0: Ushuaia.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-46.05,', "'lat':", '60.92}']
# ---------------
# Narsaq
# Retrieving Results for Index 1: Narsaq.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '19.23,', "'lat':", '-34.42}']
# ---------------
# Hermanus
# Retrieving Results for Index 2: Hermanus.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-70.92,', "'lat':", '-53.15}']
# ---------------
# Punta Arenas
# Retrieving Results for Index 3: Punta Arenas.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-92.27,', "'lat':", '15.77}']
# ---------------
# Chicomuselo
# Retrieving Results for Index 4: Chicomuselo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '128.87,', "'lat':", '71.69}']
# ---------------
# Tiksi
# Retrieving Results for Index 5: Tiksi.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '25.57,', "'lat':", '-33.92}']
# ---------------
# Port Elizabeth
# Retrieving Results for Index 6: Port Elizabeth.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-84.53,', "'lat':", '39.18}']
# ---------------
# Hamilton
# Retrieving Results for Index 7: Hamilton.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '27.91,', "'lat':", '-33.02}']
# ---------------
# East London
# Retrieving Results for Index 8: East London.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '72.89,', "'lat':", '2.67}']
# ---------------
# Kudahuvadhoo
# Retrieving Results for Index 9: Kudahuvadhoo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '147.33,', "'lat':", '-42.88}']
# ---------------
# Hobart
# Retrieving Results for Index 10: Hobart.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-133.04,', "'lat':", '69.45}']
# ---------------
# Tuktoyaktuk
# Retrieving Results for Index 11: Tuktoyaktuk.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '20.04,', "'lat':", '-34.53}']
# ---------------
# Bredasdorp
# Retrieving Results for Index 12: Bredasdorp.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-73.41,', "'lat':", '41.37}']
# ---------------
# Bethel
# Retrieving Results for Index 13: Bethel.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '24.66,', "'lat':", '71}']
# ---------------
# Havøysund
# Retrieving Results for Index 14: Havøysund.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-56.49,', "'lat':", '-2.1}']
# ---------------
# Terra Santa
# Retrieving Results for Index 15: Terra Santa.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '168.86,', "'lat':", '-46.19}']
# ---------------
# Mataura
# Retrieving Results for Index 16: Mataura.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '172.79,', "'lat':", '3.07}']
# ---------------
# Butaritari
# Retrieving Results for Index 17: Butaritari.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-68.51,', "'lat':", '63.75}']
# ---------------
# Iqaluit
# Retrieving Results for Index 18: Iqaluit.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '72.97,', "'lat':", '3.78}']
# ---------------
# Mahibadhoo
# Retrieving Results for Index 19: Mahibadhoo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-139.03,', "'lat':", '-9.8}']
# ---------------
# Atuona
# Retrieving Results for Index 20: Atuona.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '147.18,', "'lat':", '-9.44}']
# ---------------
# Port Moresby
# Retrieving Results for Index 21: Port Moresby.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-159.78,', "'lat':", '-21.21}']
# ---------------
# Avarua
# Retrieving Results for Index 22: Avarua.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '135.87,', "'lat':", '-34.73}']
# ---------------
# Port Lincoln
# Retrieving Results for Index 23: Port Lincoln.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '21.87,', "'lat':", '-23.97}']
# ---------------
# Lehututu
# Retrieving Results for Index 24: Lehututu.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '13.07,', "'lat':", '52.4}']
# ---------------
# Potsdam
# Retrieving Results for Index 25: Potsdam.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '18.42,', "'lat':", '-33.93}']
# ---------------
# Cape Town
# Retrieving Results for Index 26: Cape Town.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '116.85,', "'lat':", '-20.74}']
# ---------------
# Karratha
# Retrieving Results for Index 27: Karratha.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-122.43,', "'lat':", '37.46}']
# ---------------
# Half Moon Bay
# Retrieving Results for Index 28: Half Moon Bay.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '130.32,', "'lat':", '31.42}']
# ---------------
# Kaseda-shirakame
# Retrieving Results for Index 29: Kaseda-shirakame.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '26.89,', "'lat':", '-33.59}']
# ---------------
# Port Alfred
# Retrieving Results for Index 30: Port Alfred.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-28.7,', "'lat':", '38.52}']
# ---------------
# Ribeira Grande
# Retrieving Results for Index 31: Ribeira Grande.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '1.01,', "'lat':", '20.2}']
# ---------------
# Tessalit
# Retrieving Results for Index 32: Tessalit.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-134.97,', "'lat':", '-23.12}']
# ---------------
# Rikitea
# Retrieving Results for Index 33: Rikitea.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '55.77,', "'lat':", '-21.36}']
# ---------------
# Saint-Philippe
# Retrieving Results for Index 34: Saint-Philippe.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-135.01,', "'lat':", '68.22}']
# ---------------
# Aklavik
# Retrieving Results for Index 36: Aklavik.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-50.01,', "'lat':", '-24.79}']
# ---------------
# Castro
# Retrieving Results for Index 38: Castro.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-152.41,', "'lat':", '57.79}']
# ---------------
# Saint Paul Harbor
# Retrieving Results for Index 39: Saint Paul Harbor.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '91.82,', "'lat':", '56.17}']
# ---------------
# Kedrovyy
# Retrieving Results for Index 40: Kedrovyy.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-74.17,', "'lat':", '40.74}']
# ---------------
# Newark
# Retrieving Results for Index 41: Newark.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '102.27,', "'lat':", '-3.8}']
# ---------------
# Bengkulu
# Retrieving Results for Index 42: Bengkulu.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-126.83,', "'lat':", '65.28}']
# ---------------
# Norman Wells
# Retrieving Results for Index 43: Norman Wells.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '73.08,', "'lat':", '-0.6}']
# ---------------
# Hithadhoo
# Retrieving Results for Index 44: Hithadhoo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '110.25,', "'lat':", '-7.94}']
# ---------------
# Srandakan
# Retrieving Results for Index 45: Srandakan.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '114.08,', "'lat':", '71.92}']
# ---------------
# Saskylakh
# Retrieving Results for Index 46: Saskylakh.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '102.28,', "'lat':", '60.34}']
# ---------------
# Vanavara
# Retrieving Results for Index 47: Vanavara.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '103.64,', "'lat':", '-3.75}']
# ---------------
# Payo
# Retrieving Results for Index 48: Payo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-173.98,', "'lat':", '-18.65}']
# ---------------
# Neiafu
# Retrieving Results for Index 49: Neiafu.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-52.1,', "'lat':", '-32.03}']
# ---------------
# Rio Grande
# Retrieving Results for Index 51: Rio Grande.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '153.62,', "'lat':", '-28.65}']
# ---------------
# Byron Bay
# Retrieving Results for Index 52: Byron Bay.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '145.57,', "'lat':", '43.32}']
# ---------------
# Nemuro
# Retrieving Results for Index 53: Nemuro.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-69.36,', "'lat':", '77.48}']
# ---------------
# Qaanaaq
# Retrieving Results for Index 54: Qaanaaq.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '106.27,', "'lat':", '45.76}']
# ---------------
# Mandalgovi
# Retrieving Results for Index 55: Mandalgovi.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '140.83,', "'lat':", '35.73}']
# ---------------
# Hasaki
# Retrieving Results for Index 56: Hasaki.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '169.85,', "'lat':", '-46.28}']
# ---------------
# Kaitangata
# Retrieving Results for Index 57: Kaitangata.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-158.01,', "'lat':", '21.32}']
# ---------------
# ‘Ewa Beach
# Retrieving Results for Index 58: ‘Ewa Beach.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-73.97,', "'lat':", '42.6}']
# ---------------
# Albany
# Retrieving Results for Index 59: Albany.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '168.33,', "'lat':", '-46.6}']
# ---------------
# Bluff
# Retrieving Results for Index 61: Bluff.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-51.1,', "'lat':", '69.22}']
# ---------------
# Ilulissat
# Retrieving Results for Index 62: Ilulissat.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-54.55,', "'lat':", '-21.8}']
# ---------------
# Rio Brilhante
# Retrieving Results for Index 64: Rio Brilhante.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '109.3,', "'lat':", '13.08}']
# ---------------
# Tuy Hoa
# Retrieving Results for Index 65: Tuy Hoa.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-17.34,', "'lat':", '66.04}']
# ---------------
# Husavik
# Retrieving Results for Index 66: Husavik.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '57.7,', "'lat':", '-20.41}']
# ---------------
# Mahébourg
# Retrieving Results for Index 67: Mahébourg.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '121.9,', "'lat':", '-33.87}']
# ---------------
# Esperance
# Retrieving Results for Index 68: Esperance.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-73.39,', "'lat':", '7.76}']
# ---------------
# San Alberto
# Retrieving Results for Index 70: San Alberto.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '78.49,', "'lat':", '30.69}']
# ---------------
# Ginda
# Retrieving Results for Index 71: Ginda.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '72.93,', "'lat':", '0.53}']
# ---------------
# Thinadhoo
# Retrieving Results for Index 72: Thinadhoo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-57.56,', "'lat':", '-38}']
# ---------------
# Mar del Plata
# Retrieving Results for Index 73: Mar del Plata.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-65.71,', "'lat':", '66.15}']
# ---------------
# Pangnirtung
# Retrieving Results for Index 74: Pangnirtung.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-49.67,', "'lat':", '61.99}']
# ---------------
# Paamiut
# Retrieving Results for Index 75: Paamiut.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '147.92,', "'lat':", '70.63}']
# ---------------
# Chokurdakh
# Retrieving Results for Index 76: Chokurdakh.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-67.74,', "'lat':", '47.05}']
# ---------------
# Grand Falls
# Retrieving Results for Index 77: Grand Falls.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-89.6,', "'lat':", '-0.9}']
# ---------------
# Puerto Baquerizo Moreno
# Retrieving Results for Index 78: Puerto Baquerizo Moreno.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '57.76,', "'lat':", '-20.34}']
# ---------------
# Bambous Virieux
# Retrieving Results for Index 79: Bambous Virieux.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-42.03,', "'lat':", '-22.97}']
# ---------------
# Arraial do Cabo
# Retrieving Results for Index 80: Arraial do Cabo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '115.33,', "'lat':", '-33.65}']
# ---------------
# Busselton
# Retrieving Results for Index 81: Busselton.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-78,', "'lat':", '20.71}']
# ---------------
# Santa Cruz del Sur
# Retrieving Results for Index 82: Santa Cruz del Sur.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-79.24,', "'lat':", '42.1}']
# ---------------
# Jamestown
# Retrieving Results for Index 84: Jamestown.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-175.2,', "'lat':", '-21.2}']
# ---------------
# Vaini
# Retrieving Results for Index 86: Vaini.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '150.67,', "'lat':", '-10.62}']
# ---------------
# Samarai
# Retrieving Results for Index 88: Samarai.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '135.37,', "'lat':", '33.73}']
# ---------------
# Tanabe
# Retrieving Results for Index 89: Tanabe.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '57.61,', "'lat':", '-19.98}']
# ---------------
# Cap Malheureux
# Retrieving Results for Index 90: Cap Malheureux.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-56.15,', "'lat':", '72.79}']
# ---------------
# Upernavik
# Retrieving Results for Index 91: Upernavik.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-9.27,', "'lat':", '51.55}']
# ---------------
# Skibbereen
# Retrieving Results for Index 92: Skibbereen.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '79.62,', "'lat':", '17.15}']
# ---------------
# Suriāpet
# Retrieving Results for Index 93: Suriāpet.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-108.5,', "'lat':", '39.08}']
# ---------------
# Fruitvale
# Retrieving Results for Index 94: Fruitvale.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '156.12,', "'lat':", '50.68}']
# ---------------
# Severo-Kuril'sk
# Retrieving Results for Index 95: Severo-Kuril'sk.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '155.48,', "'lat':", '-6.32}']
# ---------------
# Panguna
# Retrieving Results for Index 96: Panguna.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '50.81,', "'lat':", '9.49}']
# ---------------
# Bandarbeyla
# Retrieving Results for Index 97: Bandarbeyla.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '102.42,', "'lat':", '18.5}']
# ---------------
# Phonhong
# Retrieving Results for Index 98: Phonhong.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '57.52,', "'lat':", '-20.52}']
# ---------------
# Souillac
# Retrieving Results for Index 99: Souillac.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '56.14,', "'lat':", '55.22}']
# ---------------
# Yazykovo
# Retrieving Results for Index 101: Yazykovo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '11.92,', "'lat':", '50.32}']
# ---------------
# Hof
# Retrieving Results for Index 102: Hof.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '124.89,', "'lat':", '-9.11}']
# ---------------
# Atambua
# Retrieving Results for Index 103: Atambua.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '152.43,', "'lat':", '-3.67}']
# ---------------
# Namatanai
# Retrieving Results for Index 104: Namatanai.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '54.37,', "'lat':", '39.51}']
# ---------------
# Balkanabat
# Retrieving Results for Index 105: Balkanabat.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-114.35,', "'lat':", '62.46}']
# ---------------
# Yellowknife
# Retrieving Results for Index 106: Yellowknife.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '119.78,', "'lat':", '16.13}']
# ---------------
# Aloleng
# Retrieving Results for Index 107: Aloleng.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-73.65,', "'lat':", '-37.62}']
# ---------------
# Lebu
# Retrieving Results for Index 108: Lebu.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-40.29,', "'lat':", '-20.33}']
# ---------------
# Vila Velha
# Retrieving Results for Index 110: Vila Velha.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '6.13,', "'lat':", '62.58}']
# ---------------
# Roald
# Retrieving Results for Index 111: Roald.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-135.33,', "'lat':", '57.05}']
# ---------------
# Sitka
# Retrieving Results for Index 112: Sitka.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-37.64,', "'lat':", '65.61}']
# ---------------
# Tasiilaq
# Retrieving Results for Index 113: Tasiilaq.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-35.46,', "'lat':", '-5.2}']
# ---------------
# Touros
# Retrieving Results for Index 114: Touros.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '114.16,', "'lat':", '22.29}']
# ---------------
# Hong Kong
# Retrieving Results for Index 115: Hong Kong.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-15.65,', "'lat':", '28.15}']
# ---------------
# Gáldar
# Retrieving Results for Index 116: Gáldar.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-97.86,', "'lat':", '55.74}']
# ---------------
# Thompson
# Retrieving Results for Index 117: Thompson.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '18.13,', "'lat':", '-26.58}']
# ---------------
# Keetmanshoop
# Retrieving Results for Index 118: Keetmanshoop.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '167.72,', "'lat':", '-45.42}']
# ---------------
# Te Anau
# Retrieving Results for Index 119: Te Anau.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-155.09,', "'lat':", '19.73}']
# ---------------
# Hilo
# Retrieving Results for Index 120: Hilo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '125.41,', "'lat':", '-8.93}']
# ---------------
# Airai
# Retrieving Results for Index 122: Airai.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '119.9,', "'lat':", '-2.97}']
# ---------------
# Rantepao
# Retrieving Results for Index 123: Rantepao.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '102.5,', "'lat':", '71.97}']
# ---------------
# Khatanga
# Retrieving Results for Index 124: Khatanga.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '131.25,', "'lat':", '-0.88}']
# ---------------
# Sorong
# Retrieving Results for Index 125: Sorong.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-15.54,', "'lat':", '27.91}']
# ---------------
# Santa Lucía
# Retrieving Results for Index 126: Santa Lucía.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-55.08,', "'lat':", '-26.72}']
# ---------------
# Natalio
# Retrieving Results for Index 128: Natalio.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-110.22,', "'lat':", '23.45}']
# ---------------
# Todos Santos
# Retrieving Results for Index 129: Todos Santos.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-52.73,', "'lat':", '47.67}']
# ---------------
# Torbay
# Retrieving Results for Index 130: Torbay.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-46.02,', "'lat':", '-1.2}']
# ---------------
# Carutapera
# Retrieving Results for Index 131: Carutapera.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '126.17,', "'lat':", '6.37}']
# ---------------
# Pundaguitan
# Retrieving Results for Index 132: Pundaguitan.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '42.45,', "'lat':", '18.39}']
# ---------------
# Faya
# Retrieving Results for Index 133: Faya.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '35.26,', "'lat':", '-16.92}']
# ---------------
# Nsanje
# Retrieving Results for Index 134: Nsanje.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-54.33,', "'lat':", '-34.48}']
# ---------------
# Rocha
# Retrieving Results for Index 135: Rocha.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-66.9,', "'lat':", '-4.88}']
# ---------------
# Carauari
# Retrieving Results for Index 136: Carauari.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-90.35,', "'lat':", '-0.74}']
# ---------------
# Puerto Ayora
# Retrieving Results for Index 137: Puerto Ayora.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '30.79,', "'lat':", '59.7}']
# ---------------
# Nikolskoye
# Retrieving Results for Index 138: Nikolskoye.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-2.93,', "'lat':", '35.17}']
# ---------------
# Nador
# Retrieving Results for Index 139: Nador.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '108.27,', "'lat':", '-2.88}']
# ---------------
# Manggar
# Retrieving Results for Index 140: Manggar.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '94.52,', "'lat':", '25.97}']
# ---------------
# Zunheboto
# Retrieving Results for Index 141: Zunheboto.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-8.95,', "'lat':", '53.95}']
# ---------------
# Swinford
# Retrieving Results for Index 142: Swinford.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-171,', "'lat':", '65.58}']
# ---------------
# Lavrentiya
# Retrieving Results for Index 143: Lavrentiya.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '115.13,', "'lat':", '50.52}']
# ---------------
# Nizhniy Tsasuchey
# Retrieving Results for Index 144: Nizhniy Tsasuchey.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-114.06,', "'lat':", '27.98}']
# ---------------
# Guerrero Negro
# Retrieving Results for Index 145: Guerrero Negro.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '133.88,', "'lat':", '-23.7}']
# ---------------
# Alice Springs
# Retrieving Results for Index 146: Alice Springs.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '80.54,', "'lat':", '5.95}']
# ---------------
# Matara
# Retrieving Results for Index 147: Matara.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '81.48,', "'lat':", '6.8}']
# ---------------
# Wattegama
# Retrieving Results for Index 148: Wattegama.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '115.83,', "'lat':", '22.81}']
# ---------------
# Jieshi
# Retrieving Results for Index 149: Jieshi.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-53.46,', "'lat':", '-33.7}']
# ---------------
# Chui
# Retrieving Results for Index 151: Chui.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-76.22,', "'lat':", '-13.7}']
# ---------------
# Pisco
# Retrieving Results for Index 152: Pisco.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '164.7,', "'lat':", '-20.97}']
# ---------------
# Voh
# Retrieving Results for Index 154: Voh.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-2.51,', "'lat':", '43.08}']
# ---------------
# Udala
# Retrieving Results for Index 155: Udala.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-81.44,', "'lat':", '26.76}']
# ---------------
# LaBelle
# Retrieving Results for Index 156: LaBelle.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-159.32,', "'lat':", '22.08}']
# ---------------
# Kapaa
# Retrieving Results for Index 158: Kapaa.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '122.79,', "'lat':", '-0.95}']
# ---------------
# Luwuk
# Retrieving Results for Index 159: Luwuk.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ...
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '123.72,', "'lat':", '50.57}']
# ---------------
# Alihe
# Retrieving Results for Index 446: Alihe.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '150.87,', "'lat':", '-34.68}']
# ---------------
# Kiama
# Retrieving Results for Index 447: Kiama.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '57.68,', "'lat':", '36.21}']
# ---------------
# Sabzawār
# Retrieving Results for Index 448: Sabzawār.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-87.63,', "'lat':", '46.53}']
# ---------------
# Marquette
# Retrieving Results for Index 449: Marquette.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-91.21,', "'lat':", '29.7}']
# ---------------
# Morgan City
# Retrieving Results for Index 450: Morgan City.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '133.9,', "'lat':", '43.38}']
# ---------------
# Lazo
# Retrieving Results for Index 452: Lazo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '31.11,', "'lat':", '70.37}']
# ---------------
# Vardø
# Retrieving Results for Index 453: Vardø.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '113.15,', "'lat':", '27.83}']
# ---------------
# Jianning
# Retrieving Results for Index 454: Jianning.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '135.98,', "'lat':", '33.73}']
# ---------------
# Shingū
# Retrieving Results for Index 455: Shingū.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-72.22,', "'lat':", '7.77}']
# ---------------
# San Cristobal
# Retrieving Results for Index 456: San Cristobal.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '92.75,', "'lat':", '11.67}']
# ---------------
# Port Blair
# Retrieving Results for Index 457: Port Blair.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-18.53,', "'lat':", '65.97}']
# ---------------
# Dalvik
# Retrieving Results for Index 458: Dalvik.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '113.83,', "'lat':", '23.3}']
# ---------------
# Licheng
# Retrieving Results for Index 460: Licheng.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-76.9,', "'lat':", '34.88}']
# ---------------
# Havelock
# Retrieving Results for Index 461: Havelock.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '16.05,', "'lat':", '1.61}']
# ---------------
# Ouésso
# Retrieving Results for Index 462: Ouésso.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '36.53,', "'lat':", '61.81}']
# ---------------
# Pudozh
# Retrieving Results for Index 463: Pudozh.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '32.27,', "'lat':", '30.6}']
# ---------------
# Ismailia
# Retrieving Results for Index 464: Ismailia.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '53.3,', "'lat':", '36.65}']
# ---------------
# Nekā
# Retrieving Results for Index 465: Nekā.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-36.43,', "'lat':", '-10.41}']
# ---------------
# Piaçabuçu
# Retrieving Results for Index 466: Piaçabuçu.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-149.44,', "'lat':", '61.58}']
# ---------------
# Wasilla
# Retrieving Results for Index 467: Wasilla.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '1.73,', "'lat':", '52.61}']
# ---------------
# Great Yarmouth
# Retrieving Results for Index 468: Great Yarmouth.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-151.26,', "'lat':", '60.55}']
# ---------------
# Kenai
# Retrieving Results for Index 470: Kenai.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-52.21,', "'lat':", '-3.2}']
# ---------------
# Altamira
# Retrieving Results for Index 471: Altamira.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-80.34,', "'lat':", '-4.93}']
# ---------------
# Tambo Grande
# Retrieving Results for Index 472: Tambo Grande.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-22.43,', "'lat':", '63.84}']
# ---------------
# Grindavik
# Retrieving Results for Index 473: Grindavik.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '8.57,', "'lat':", '7.38}']
# ---------------
# Yaan
# Retrieving Results for Index 474: Yaan.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-82.43,', "'lat':", '49.42}']
# ---------------
# Kapuskasing
# Retrieving Results for Index 476: Kapuskasing.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-96.99,', "'lat':", '33.05}']
# ---------------
# Lewisville
# Retrieving Results for Index 477: Lewisville.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-149.27,', "'lat':", '-17.83}']
# ---------------
# Teahupoo
# Retrieving Results for Index 478: Teahupoo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '77.24,', "'lat':", '38.42}']
# ---------------
# Shache
# Retrieving Results for Index 479: Shache.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '57.66,', "'lat':", '-20.01}']
# ---------------
# Grand Gaube
# Retrieving Results for Index 480: Grand Gaube.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '78.7,', "'lat':", '67.47}']
# ---------------
# Tazovsky
# Retrieving Results for Index 481: Tazovsky.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '81.93,', "'lat':", '21.73}']
# ---------------
# Bhātāpāra
# Retrieving Results for Index 482: Bhātāpāra.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-75.83,', "'lat':", '42.25}']
# ---------------
# Broome
# Retrieving Results for Index 483: Broome.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-76.2,', "'lat':", '24.9}']
# ---------------
# Rock Sound
# Retrieving Results for Index 484: Rock Sound.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '101.71,', "'lat':", '26.59}']
# ---------------
# Panzhihua
# Retrieving Results for Index 485: Panzhihua.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-86.29,', "'lat':", '36.21}']
# ---------------
# Lebanon
# Retrieving Results for Index 486: Lebanon.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-89.67,', "'lat':", '21.28}']
# ---------------
# Progreso
# Retrieving Results for Index 487: Progreso.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '125.51,', "'lat':", '12.18}']
# ---------------
# San Policarpo
# Retrieving Results for Index 488: San Policarpo.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '159.23,', "'lat':", '61.95}']
# ---------------
# Evensk
# Retrieving Results for Index 489: Evensk.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-70.4,', "'lat':", '-23.65}']
# ---------------
# Antofagasta
# Retrieving Results for Index 490: Antofagasta.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-66.77,', "'lat':", '-18.9}']
# ---------------
# Challapata
# Retrieving Results for Index 491: Challapata.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '-86.33,', "'lat':", '34.38}']
# ---------------
# Marshall
# Retrieving Results for Index 492: Marshall.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '58.53,', "'lat':", '56.42}']
# ---------------
# Arti
# Retrieving Results for Index 493: Arti.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '29.09,', "'lat':", '70.86}']
# ---------------
# Berlevåg
# Retrieving Results for Index 494: Berlevåg.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '86.15,', "'lat':", '41.76}']
# ---------------
# Korla
# Retrieving Results for Index 495: Korla.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '20.58,', "'lat':", '32.53}']
# ---------------
# Tūkrah
# Retrieving Results for Index 496: Tūkrah.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------
# ---------------
# ["{'lon':", '8.48,', "'lat':", '35.86}']
# ---------------
# Menzel Salem
# Retrieving Results for Index 499: Menzel Salem.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-34.42,19.23&radius=50000&name=hotel&key=AIzaSyBZwPQ-pWVfBztTaSX7TVDOgRr8dzuONsQ
# Closest hotel is De Molen Guesthouse.
# ------------

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
fig

# Display Map
# Out:
# Figure(layout=FigureLayout(height='420px'))
